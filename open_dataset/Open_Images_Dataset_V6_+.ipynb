# %% [markdown]
# **Open Images Dataset V6 +**

# %%
# !nvidia-smi
# Out:
# Thu Jan 13 06:31:15 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# Out:
# Cloning into 'OIDv4_ToolKit'...
# remote: Enumerating objects: 422, done.
# remote: Total 422 (delta 0), reused 0 (delta 0), pack-reused 422
# Receiving objects: 100% (422/422), 34.08 MiB | 40.96 MiB/s, done.
# Resolving deltas: 100% (146/146), done.

# %%
# !pip3 install -r /content/OIDv4_ToolKit/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 3.8 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.8 MB/s
# ...
#      |████████████████████████████████| 547 kB 60.9 MB/s
# ...
#      |████████████████████████████████| 8.5 MB 52.8 MB/s
# ...
#      |████████████████████████████████| 138 kB 37.0 MB/s
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: rsa
#     Found existing installation: rsa 4.8
#     Uninstalling rsa-4.8:
#       Successfully uninstalled rsa-4.8
#   Attempting uninstall: docutils
#     Found existing installation: docutils 0.17.1
#     Uninstalling docutils-0.17.1:
#       Successfully uninstalled docutils-0.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Person --type_csv train --limit 2000
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Person.
#    [ERROR] | Missing the train-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] y
# ...100%, 1138 MB, 44055 KB/s, 26 seconds passed
# ...

# %% [markdown]
# **I download the images and i need to pre process for my training model**

# %%
# !python /content/OIDv4_ToolKit/main.py downloader --classes Man Woman Dog --type_csv test --limit 50
# Out:
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading Man.
#    [ERROR] | Missing the test-annotations-bbox.csv file.
# [DOWNLOAD] | Do you want to download the missing file? [Y/n] Y
# ...100%, 49 MB, 49154 KB/s, 1 seconds passed
# [DOWNLOAD] | File test-annotations-bbox.csv downloaded into OID/csv_folder/test-annotations-bbox.csv.
# ...

# %%
# !zip -r /content/file.zip /content/OID
# Out:
#   adding: content/OID/ (stored 0%)
#   adding: content/OID/csv_folder/ (stored 0%)
#   adding: content/OID/csv_folder/train-annotations-bbox.csv (deflated 79%)
#   adding: content/OID/csv_folder/class-descriptions-boxable.csv (deflated 51%)
#   adding: content/OID/Dataset/ (stored 0%)
#   adding: content/OID/Dataset/train/ (stored 0%)
#   adding: content/OID/Dataset/train/person/ (stored 0%)
#   adding: content/OID/Dataset/train/person/Label/ (stored 0%)
#   adding: content/OID/Dataset/train/Person/ (stored 0%)
#   adding: content/OID/Dataset/train/Person/e70f198a077d95f5.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/c1be7e45d09d5ded.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/775d079f18462a3a.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/c369b88e64a88fa1.jpg (deflated 1%)
#   adding: content/OID/Dataset/train/Person/75d409fa89689993.jpg (deflated 0%)
#   adding: content/OID/Dataset/train/Person/9eb5841caeef5f45.jpg (deflated 0%)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp "/content/file.zip" "/content/drive/MyDrive/comapny dataset"
